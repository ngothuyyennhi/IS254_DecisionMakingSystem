# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error

# %%
from google.colab import drive
drive.mount('/content/drive')
drive_path = '/content/drive/My Drive/DataHHTQD/MovieData/'
# Out:
# Mounted at /content/drive

# %%
ratings = pd.read_csv(drive_path + 'ratings.csv')
movies = pd.read_csv(drive_path + 'movies.csv')

# %%
top_users = ratings['userId'].value_counts().nlargest(1000).index
top_movies = ratings['movieId'].value_counts().nlargest(1000).index

# %%
filtered_ratings = ratings[ratings['userId'].isin(top_users) & ratings['movieId'].isin(top_movies)]

# %%
merge_df=pd.merge(movies,filtered_ratings,on='movieId')
merge_df
# Out:
#         movieId              title  \
# 0             1   Toy Story (1995)
# 1             1   Toy Story (1995)
# 2             1   Toy Story (1995)
# 3             1   Toy Story (1995)
# 4             1   Toy Story (1995)
# ...         ...                ...
# 646980   207313  Knives Out (2019)
# 646981   207313  Knives Out (2019)
# 646982   207313  Knives Out (2019)
# 646983   207313  Knives Out (2019)
# 646984   207313  Knives Out (2019)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy      28     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy     188     4.0
# 2       Adventure|Animation|Children|Comedy|Fantasy     265     5.0
# 3       Adventure|Animation|Children|Comedy|Fantasy    1048     4.0
# 4       Adventure|Animation|Children|Comedy|Fantasy    1411     4.0
# ...                                             ...     ...     ...
# 646980          Comedy|Crime|Drama|Mystery|Thriller  199718     3.5
# 646981          Comedy|Crime|Drama|Mystery|Thriller  199816     4.0
# 646982          Comedy|Crime|Drama|Mystery|Thriller  199966     4.5
# 646983          Comedy|Crime|Drama|Mystery|Thriller  200323     4.0
# 646984          Comedy|Crime|Drama|Mystery|Thriller  200578     4.0
#
#          timestamp
# 0        961438127
# 1       1103751789
# 2       1607904458
# 3       1619382182
# 4       1322832011
# ...            ...
# 646980  1620242560
# 646981  1619410044
# 646982  1603193038
# 646983  1642100833
# 646984  1581666500
#
# [646985 rows x 6 columns]

# %%
user_movie_matrix=merge_df.pivot_table(index='userId', columns='title', values='rating').fillna(0)
user_movie_matrix
# Out:
# title   (500) Days of Summer (2009)  10 Things I Hate About You (1999)  \
# userId
# 28                              4.0                                4.0
# 188                             3.5                                4.5
# 265                             4.5                                3.5
# 1048                            3.5                                0.0
# 1411                            4.0                                4.0
# ...                             ...                                ...
# 199816                          4.5                                3.5
# 199966                          0.0                                0.0
# 200322                          0.0                                0.0
# 200323                          2.5                                3.0
# 200578                          0.0                                0.0
#
# title   101 Dalmatians (1996)  \
# userId
# 28                        0.0
# 188                       2.5
# 265                       0.0
# 1048                      1.5
# 1411                      3.0
# ...                       ...
# 199816                    0.0
# 199966                    2.0
# 200322                    0.0
# 200323                    1.5
# 200578                    0.0
#
# title   101 Dalmatians (One Hundred and One Dalmatians) (1961)  \
# userId
# 28                                                    4.0
# 188                                                   4.5
# 265                                                   0.0
# 1048                                                  0.0
# 1411                                                  0.0
# ...                                                   ...
# 199816                                                0.0
# 199966                                                3.0
# 200322                                                0.0
# 200323                                                0.0
# 200578                                                3.0
#
# title   12 Angry Men (1957)  12 Years a Slave (2013)  127 Hours (2010)  \
# userId
# 28                      0.0                      0.0               0.0
# 188                     4.0                      0.0               0.0
# 265                     5.0                      0.0               3.0
# 1048                    4.5                      4.5               3.0
# 1411                    0.0                      0.0               4.0
# ...                     ...                      ...               ...
# 199816                  4.0                      5.0               4.0
# 199966                  4.0                      3.5               0.0
# 200322                  4.0                      0.0               0.0
# 200323                  4.5                      3.0               3.0
# 200578                  5.0                      4.0               3.5
#
# title   13th Warrior, The (1999)  2001: A Space Odyssey (1968)  2012 (2009)  \
# userId
# 28                           3.0                           5.0          2.0
# 188                          0.0                           4.0          0.0
# 265                          0.0                           0.0          0.5
# 1048                         2.5                           5.0          3.0
# 1411                         3.0                           2.5          4.0
# ...                          ...                           ...          ...
# 199816                       3.0                           0.5          2.5
# 199966                       2.0                           5.0          0.0
# 200322                       4.0                           1.5          2.0
# 200323                       2.0                           1.0          2.0
# 200578                       2.5                           4.0          1.5
#
# title   ...  X-Men: First Class (2011)  X-Men: The Last Stand (2006)  \
# userId  ...
# 28      ...                        3.5                           3.5
# 188     ...                        0.0                           0.0
# 265     ...                        4.0                           3.0
# 1048    ...                        3.5                           3.5
# 1411    ...                        0.0                           0.0
# ...     ...                        ...                           ...
# 199816  ...                        0.0                           3.0
# 199966  ...                        0.0                           0.0
# 200322  ...                        4.0                           2.5
# 200323  ...                        3.5                           3.0
# 200578  ...                        4.0                           2.5
#
# title   X2: X-Men United (2003)  Yes Man (2008)  You've Got Mail (1998)  \
# userId
# 28                          4.0             0.0                     3.5
# 188                         0.0             1.0                     4.5
# 265                         2.5             1.5                     3.5
# 1048                        4.0             2.0                     2.5
# 1411                        0.0             4.0                     4.5
# ...                         ...             ...                     ...
# 199816                      3.5             0.0                     3.0
# 199966                      2.0             0.0                     0.0
# 200322                      3.0             2.5                     0.0
# 200323                      3.0             3.0                     3.0
# 200578                      4.0             0.0                     2.5
#
# title   Young Frankenstein (1974)  Zodiac (2007)  Zombieland (2009)  \
# userId
# 28                            4.0            3.5                5.0
# 188                           3.0            5.0                4.0
# 265                           5.0            5.0                2.5
# 1048                          2.5            3.0                2.0
# 1411                          0.0            0.0                2.5
# ...                           ...            ...                ...
# 199816                        0.0            4.5                4.0
# 199966                        4.0            0.0                0.0
# 200322                        4.0            3.0                3.5
# 200323                        0.0            3.0                0.0
# 200578                        3.0            3.5                3.0
#
# title   Zoolander (2001)  Zootopia (2016)
# userId
# 28                   4.0              4.0
# 188                  2.0              0.0
# 265                  5.0              0.0
# 1048                 3.5              3.5
# 1411                 3.5              0.0
# ...                  ...              ...
# 199816               2.5              4.0
# 199966               3.0              3.0
# 200322               3.0              3.5
# 200323               0.0              3.0
# 200578               2.5              0.0
#
# [1000 rows x 1000 columns]

# %%
R = user_movie_matrix.to_numpy()

# %%
def train_test_split(R, test_size=0.2):
    indices = np.array(np.where(~np.isnan(R))).T
    n_samples = indices.shape[0]
    np.random.shuffle(indices)

    n_test_samples = int(n_samples * test_size)
    test_indices = indices[:n_test_samples]
    train_indices = indices[n_test_samples:]

    R_train = R.copy()
    R_test = np.full_like(R, fill_value=np.nan, dtype=float)

    for i, j in test_indices:
        R_test[i, j] = R[i, j]
        R_train[i, j] = np.nan

    return R_train, R_test, train_indices, test_indices

# %%
def matrix_factorization(R_train, k=3, n_epochs=50, learning_rate=0.01, lambda_reg=0.1):
    n_users, n_items = R_train.shape
    U = np.random.rand(n_users, k)
    V = np.random.rand(n_items, k)

    # Huấn luyện mô hình
    for epoch in range(n_epochs):
        for i in range(n_users):
            for j in range(n_items):
                if not np.isnan(R_train[i, j]):
                    # Tính toán lỗi
                    error = R_train[i, j] - np.dot(U[i, :], V[j, :].T)
                    # Cập nhật các yếu tố
                    U[i, :] += learning_rate * (error * V[j, :] - lambda_reg * U[i, :])
                    V[j, :] += learning_rate * (error * U[i, :] - lambda_reg * V[j, :])

        # In loss sau mỗi epoch
        if epoch % 10 == 0:
            loss = np.nansum((R_train - np.dot(U, V.T)) ** 2)
            print(f'Epoch {epoch}, Loss: {loss}')

    return U, V

# %%
def predict_rating(U, V, user_id, item_id):
    return np.dot(U[user_id, :], V[item_id, :].T)

# %%
def evaluate_model(U, V, R_test):
    predictions = []
    true_ratings = []

    for i, j in zip(*np.where(~np.isnan(R_test))):
        predicted_rating = predict_rating(U, V, i, j)
        true_rating = R_test[i, j]

        predictions.append(predicted_rating)
        true_ratings.append(true_rating)

    rmse = np.sqrt(mean_squared_error(true_ratings, predictions))
    return rmse

# %%
R_train, R_test, train_indices, test_indices = train_test_split(R, test_size=0.2)

# %%
U, V = matrix_factorization(R_train, k=3, n_epochs=50, learning_rate=0.01, lambda_reg=0.1)
# Out:
# Epoch 0, Loss: 2335498.6351467324
# Epoch 10, Loss: 1790352.3427018593
# Epoch 20, Loss: 1790352.4273975382
# Epoch 30, Loss: 1790352.4273973336
# Epoch 40, Loss: 1790352.4273973322

# %%
userId = 0
movieId = 1

# %%
predicted_rating = predict_rating(U, V, userId, movieId)
print(f"Dự đoán rating cho User {userId+1} (người dùng {userId}) và Movie '{user_movie_matrix.columns[movieId]}' là: {predicted_rating:.2f}")
# Out:
# Dự đoán rating cho User 1 (người dùng 0) và Movie '10 Things I Hate About You (1999)' là: 3.18

# %%
rmse = evaluate_model(U, V, R_test)
print(f'RMSE trên tập kiểm tra: {rmse}')
# Out:
# RMSE trên tập kiểm tra: 1.5065621123753603
